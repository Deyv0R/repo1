# %% [markdown]
# <a href="https://colab.research.google.com/github/Deyv0R/repo1/blob/main/%D0%9A%D0%B8%D1%8F%D0%BD%D0%B8%D1%86%D1%8F_%D0%9B%D1%803.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Завантаження файлу
df = pd.read_csv('/content/drive/MyDrive/КСВД/spotify-2023.csv', encoding='latin-1')

# Перегляд перших рядків
df.head()

# Сортуємо за кількістю прослуховувань
top_songs = df.sort_values(by='streams', ascending=False).head(10)

plt.figure()
plt.barh(top_songs['track_name'], top_songs['streams'])
plt.xlabel('Кількість прослуховувань')
plt.ylabel('Пісня')
plt.title('ТОП-10 найпопулярніших пісень Spotify 2023')
plt.gca().invert_yaxis()
plt.show()

# Візьмемо топ-10 пісень
genre_data = top_songs['artist(s)_name'].value_counts()

plt.figure()
plt.pie(genre_data, labels=genre_data.index, autopct='%1.1f%%')
plt.title('Розподіл артистів серед ТОП-10 пісень')
plt.show()

import numpy as np

track = df.iloc[0]  # беремо будь-який трек
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(
    '/content/drive/MyDrive/КСВД/spotify-2023.csv',
    encoding='latin-1',
    on_bad_lines='skip'
)

# Очистка streams
df['streams'] = pd.to_numeric(
    df['streams'].astype(str).str.replace(',', ''),
    errors='coerce'
)

df = df.dropna(subset=['streams'])

# Дані для графіка
track = df.iloc[0]

months = ['Jan','Feb','Mar','Apr','May','Jun',
          'Jul','Aug','Sep','Oct','Nov','Dec']

streams = np.linspace(0, track['streams'], 12)

plt.figure()
plt.plot(months, streams, marker='o')
plt.xlabel('Місяць')
plt.ylabel('Прослуховування')
plt.title(f"Динаміка популярності: {track['track_name']}")
plt.grid()
plt.show()
