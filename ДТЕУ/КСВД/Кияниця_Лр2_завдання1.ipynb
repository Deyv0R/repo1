# %% [markdown]
# <a href="https://colab.research.google.com/github/Deyv0R/repo1/blob/main/%D0%9A%D0%B8%D1%8F%D0%BD%D0%B8%D1%86%D1%8F_%D0%9B%D1%802_%D0%B7%D0%B0%D0%B2%D0%B4%D0%B0%D0%BD%D0%BD%D1%8F1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Зчитування CSV файлу
df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 2. Перші 5 рядків
print(df.head())
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    Urban_population   Latitude  Longitude
# 0       471031528.0  20.593684  78.962880
# 1       270663028.0  37.090240 -95.712891
# 2       270663028.0  37.090240 -95.712891
# 3       270663028.0  37.090240 -95.712891
# 4       471031528.0  20.593684  78.962880
#
# [5 rows x 28 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 3. Розмір датасету
print("Розмір:", df.shape)
# Out:
# Розмір: (995, 28)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 4. Перевірка пропусків
print(df.isna().sum())
# Якщо є пропуски — заміна на NaN і числовий тип
df = df.replace('', np.nan)

for col in df.columns:
    try:
        df[col] = pd.to_numeric(df[col])
    except:
        pass
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# created_month                                5
# created_date                                 5
# Gross tertiary education enrollment (%)    123
# Population                                 123
# Unemployment rate                          123
# Urban_population                           123
# Latitude                                   123
# Longitude                                  123
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 5. Заповнення пропусків середнім
df = df.fillna(df.mean(numeric_only=True))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 6. Перевірка ще раз
print(df.isna().sum())
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# created_month                                5
# created_date                                 5
# Gross tertiary education enrollment (%)    123
# Population                                 123
# Unemployment rate                          123
# Urban_population                           123
# Latitude                                   123
# Longitude                                  123
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 7. Кількість унікальних країн
print("Кількість країн:", df['Country'].nunique())
# Out:
# Кількість країн: 49

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 8. Гістограма переглядів
df['video views'].plot(kind='hist', bins=30)
plt.title("Розподіл переглядів")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 9. max, min, mean переглядів
print("Макс:", df['video views'].max())
print("Мін:", df['video views'].min())
print("Середнє:", df['video views'].mean())
# Out:
# Макс: 228000000000.0
# Мін: 0.0
# Середнє: 11039537052.03819

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 10. Країна з найбільшою кількістю відео
country_counts = df['Country'].value_counts()
print("Топ країна:", country_counts.idxmax())
# Out:
# Топ країна: United States

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/КСВД/Global YouTube Statistics.csv', encoding='latin-1')

# 11. Відео з max і min uploads
max_video = df.loc[df['uploads'].idxmax()]
min_video = df.loc[df['uploads'].idxmin()]

print("Макс uploads:", max_video['Title'])
print("Мін uploads:", min_video['Title'])
# Out:
# Макс uploads: ABP NEWS
# Мін uploads: Music
